# %% [markdown]
# <a href="https://colab.research.google.com/github/riamsnow/FutureMakers/blob/main/autoencoders.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Day 21 - Autoencoders

# %%
import keras
from keras import layers

# This is the size of our encoded representations
encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

# This is our input image
input_img = keras.Input(shape=(784,))
# "encoded" is the encoded representation of the input
encoded = layers.Dense(encoding_dim, activation='relu')(input_img)
# "decoded" is the lossy reconstruction of the input
decoded = layers.Dense(784, activation='sigmoid')(encoded)

# This model maps an input to its reconstruction
autoencoder = keras.Model(input_img, decoded)

# %%
# This model maps an input to its encoded representation
encoder = keras.Model(input_img, encoded)

# %%
# This is our encoded (32-dimensional) input
encoded_input = keras.Input(shape=(encoding_dim,))
# Retrieve the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-1]
# Create the decoder model
decoder = keras.Model(encoded_input, decoder_layer(encoded_input))

# %%
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
from keras.datasets import mnist
import numpy as np
(x_train, _), (x_test, _) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %%
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/50
# 235/235 [==============================] - 13s 5ms/step - loss: 0.3775 - val_loss: 0.1908
# Epoch 2/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1810 - val_loss: 0.1549
# Epoch 3/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1506 - val_loss: 0.1346
# Epoch 4/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1323 - val_loss: 0.1219
# Epoch 5/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1209 - val_loss: 0.1136
# Epoch 6/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1130 - val_loss: 0.1075
# Epoch 7/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1075 - val_loss: 0.1033
# Epoch 8/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1035 - val_loss: 0.1002
# Epoch 9/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1005 - val_loss: 0.0975
# Epoch 10/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0984 - val_loss: 0.0958
# Epoch 11/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0968 - val_loss: 0.0948
# Epoch 12/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0957 - val_loss: 0.0939
# Epoch 13/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0949 - val_loss: 0.0935
# Epoch 14/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0945 - val_loss: 0.0932
# Epoch 15/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0944 - val_loss: 0.0929
# Epoch 16/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0941 - val_loss: 0.0928
# Epoch 17/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0940 - val_loss: 0.0926
# Epoch 18/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0938 - val_loss: 0.0925
# Epoch 19/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0935 - val_loss: 0.0925
# Epoch 20/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0936 - val_loss: 0.0923
# Epoch 21/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0935 - val_loss: 0.0923
# Epoch 22/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0935 - val_loss: 0.0922
# Epoch 23/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0934 - val_loss: 0.0922
# Epoch 24/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0933 - val_loss: 0.0921
# Epoch 25/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0934 - val_loss: 0.0921
# Epoch 26/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0930 - val_loss: 0.0921
# Epoch 27/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0931 - val_loss: 0.0921
# Epoch 28/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0931 - val_loss: 0.0921
# Epoch 29/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0931 - val_loss: 0.0920
# Epoch 30/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0934 - val_loss: 0.0920
# Epoch 31/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0929 - val_loss: 0.0920
# Epoch 32/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0931 - val_loss: 0.0920
# Epoch 33/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0930 - val_loss: 0.0919
# Epoch 34/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0930 - val_loss: 0.0919
# Epoch 35/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0929 - val_loss: 0.0918
# Epoch 36/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0930 - val_loss: 0.0919
# Epoch 37/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0928 - val_loss: 0.0918
# Epoch 38/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0929 - val_loss: 0.0918
# Epoch 39/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0930 - val_loss: 0.0919
# Epoch 40/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0928 - val_loss: 0.0919
# Epoch 41/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0928 - val_loss: 0.0917
# Epoch 42/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0928 - val_loss: 0.0918
# Epoch 43/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0930 - val_loss: 0.0918
# Epoch 44/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0928 - val_loss: 0.0918
# Epoch 45/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0928 - val_loss: 0.0918
# Epoch 46/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0930 - val_loss: 0.0918
# Epoch 47/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0929 - val_loss: 0.0918
# Epoch 48/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0928 - val_loss: 0.0917
# Epoch 49/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0928 - val_loss: 0.0917
# Epoch 50/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0928 - val_loss: 0.0918

# %%
# Encode and decode some digits
# Note that we take them from the *test* set
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

# %%
# Use Matplotlib (don't ask)
import matplotlib.pyplot as plt

n = 10  # How many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
from keras import regularizers

encoding_dim = 32

input_img = keras.Input(shape=(784,))
# Add a Dense layer with a L1 activity regularizer
encoded = layers.Dense(encoding_dim, activation='relu',
                activity_regularizer=regularizers.l1(10e-5))(input_img)
decoded = layers.Dense(784, activation='sigmoid')(encoded)

autoencoder = keras.Model(input_img, decoded)

# %%
input_img = keras.Input(shape=(784,))
encoded = layers.Dense(128, activation='relu')(input_img)
encoded = layers.Dense(64, activation='relu')(encoded)
encoded = layers.Dense(32, activation='relu')(encoded)

decoded = layers.Dense(64, activation='relu')(encoded)
decoded = layers.Dense(128, activation='relu')(decoded)
decoded = layers.Dense(784, activation='sigmoid')(decoded)

# %%
autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

autoencoder.fit(x_train, x_train,
                epochs=100,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/100
# 235/235 [==============================] - 2s 4ms/step - loss: 0.3317 - val_loss: 0.1588
# Epoch 2/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1516 - val_loss: 0.1329
# Epoch 3/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1311 - val_loss: 0.1212
# Epoch 4/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1211 - val_loss: 0.1146
# Epoch 5/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1146 - val_loss: 0.1097
# Epoch 6/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1101 - val_loss: 0.1055
# Epoch 7/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1065 - val_loss: 0.1030
# Epoch 8/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1038 - val_loss: 0.1007
# Epoch 9/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1015 - val_loss: 0.0998
# Epoch 10/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1001 - val_loss: 0.0977
# Epoch 11/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0985 - val_loss: 0.0964
# Epoch 12/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0970 - val_loss: 0.0954
# Epoch 13/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0960 - val_loss: 0.0943
# Epoch 14/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0953 - val_loss: 0.0935
# Epoch 15/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0943 - val_loss: 0.0928
# Epoch 16/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0934 - val_loss: 0.0922
# Epoch 17/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0926 - val_loss: 0.0913
# Epoch 18/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0921 - val_loss: 0.0906
# Epoch 19/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0913 - val_loss: 0.0900
# Epoch 20/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0908 - val_loss: 0.0897
# Epoch 21/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0903 - val_loss: 0.0894
# Epoch 22/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0900 - val_loss: 0.0889
# Epoch 23/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0896 - val_loss: 0.0886
# Epoch 24/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0891 - val_loss: 0.0886
# Epoch 25/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0890 - val_loss: 0.0880
# Epoch 26/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0886 - val_loss: 0.0878
# Epoch 27/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0881 - val_loss: 0.0875
# Epoch 28/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0880 - val_loss: 0.0876
# Epoch 29/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0876 - val_loss: 0.0870
# Epoch 30/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0874 - val_loss: 0.0869
# Epoch 31/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0872 - val_loss: 0.0867
# Epoch 32/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0869 - val_loss: 0.0864
# Epoch 33/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0870 - val_loss: 0.0865
# Epoch 34/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0867 - val_loss: 0.0862
# Epoch 35/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0865 - val_loss: 0.0861
# Epoch 36/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0865 - val_loss: 0.0862
# Epoch 37/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0861 - val_loss: 0.0857
# Epoch 38/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0861 - val_loss: 0.0853
# Epoch 39/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0858 - val_loss: 0.0851
# Epoch 40/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0856 - val_loss: 0.0852
# Epoch 41/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0854 - val_loss: 0.0849
# Epoch 42/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0853 - val_loss: 0.0847
# Epoch 43/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0851 - val_loss: 0.0846
# Epoch 44/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0849 - val_loss: 0.0846
# Epoch 45/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0850 - val_loss: 0.0841
# Epoch 46/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0846 - val_loss: 0.0839
# Epoch 47/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0843 - val_loss: 0.0840
# Epoch 48/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0841 - val_loss: 0.0837
# Epoch 49/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0837 - val_loss: 0.0837
# Epoch 50/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0836 - val_loss: 0.0835
# Epoch 51/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0836 - val_loss: 0.0835
# Epoch 52/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0834 - val_loss: 0.0831
# Epoch 53/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0835 - val_loss: 0.0829
# Epoch 54/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0834 - val_loss: 0.0831
# Epoch 55/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0831 - val_loss: 0.0827
# Epoch 56/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0831 - val_loss: 0.0829
# Epoch 57/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0831 - val_loss: 0.0829
# Epoch 58/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0831 - val_loss: 0.0825
# Epoch 59/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0830 - val_loss: 0.0826
# Epoch 60/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0829 - val_loss: 0.0825
# Epoch 61/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0827 - val_loss: 0.0825
# Epoch 62/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0826 - val_loss: 0.0824
# Epoch 63/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0827 - val_loss: 0.0823
# Epoch 64/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0826 - val_loss: 0.0822
# Epoch 65/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0826 - val_loss: 0.0823
# Epoch 66/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0827 - val_loss: 0.0824
# Epoch 67/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0824 - val_loss: 0.0822
# Epoch 68/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0821 - val_loss: 0.0820
# Epoch 69/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0822 - val_loss: 0.0819
# Epoch 70/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0823 - val_loss: 0.0819
# Epoch 71/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0825 - val_loss: 0.0817
# Epoch 72/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0823 - val_loss: 0.0819
# Epoch 73/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0819 - val_loss: 0.0820
# Epoch 74/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0821 - val_loss: 0.0819
# Epoch 75/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0820 - val_loss: 0.0816
# Epoch 76/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0822 - val_loss: 0.0818
# Epoch 77/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0819 - val_loss: 0.0815
# Epoch 78/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0819 - val_loss: 0.0818
# Epoch 79/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0819 - val_loss: 0.0815
# Epoch 80/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0817 - val_loss: 0.0815
# Epoch 81/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0817 - val_loss: 0.0817
# Epoch 82/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0817 - val_loss: 0.0813
# Epoch 83/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0817 - val_loss: 0.0816
# Epoch 84/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0816 - val_loss: 0.0814
# Epoch 85/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0816 - val_loss: 0.0814
# Epoch 86/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0815 - val_loss: 0.0814
# Epoch 87/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0816 - val_loss: 0.0814
# Epoch 88/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0815 - val_loss: 0.0813
# Epoch 89/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0815 - val_loss: 0.0811
# Epoch 90/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0815 - val_loss: 0.0814
# Epoch 91/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0813 - val_loss: 0.0816
# Epoch 92/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0813 - val_loss: 0.0812
# Epoch 93/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0814 - val_loss: 0.0810
# Epoch 94/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0812 - val_loss: 0.0811
# Epoch 95/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0812 - val_loss: 0.0811
# Epoch 96/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0815 - val_loss: 0.0812
# Epoch 97/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0813 - val_loss: 0.0813
# Epoch 98/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0813 - val_loss: 0.0810
# Epoch 99/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0811 - val_loss: 0.0809
# Epoch 100/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0812 - val_loss: 0.0810

# %%
# Convolutional autoencoder
input_img = keras.Input(shape=(28, 28, 1))

x = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same')(x)

# at this point the representation is (4, 4, 8) i.e. 128-dimensional

x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(16, (3, 3), activation='relu')(x)
x = layers.UpSampling2D((2, 2))(x)
decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
from keras.datasets import mnist
import numpy as np

(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

# %%
from keras.callbacks import TensorBoard

autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test, x_test),
                callbacks=[TensorBoard(log_dir='/tmp/autoencoder')])
# Out:
# Epoch 1/50
# 469/469 [==============================] - 19s 8ms/step - loss: 0.2968 - val_loss: 0.1464
# Epoch 2/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1421 - val_loss: 0.1294
# Epoch 3/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1283 - val_loss: 0.1224
# Epoch 4/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1214 - val_loss: 0.1169
# Epoch 5/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1172 - val_loss: 0.1136
# Epoch 6/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1141 - val_loss: 0.1123
# Epoch 7/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1114 - val_loss: 0.1081
# Epoch 8/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1090 - val_loss: 0.1065
# Epoch 9/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1071 - val_loss: 0.1053
# Epoch 10/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1058 - val_loss: 0.1038
# Epoch 11/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1044 - val_loss: 0.1030
# Epoch 12/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1034 - val_loss: 0.1014
# Epoch 13/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1026 - val_loss: 0.1014
# Epoch 14/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1020 - val_loss: 0.0998
# Epoch 15/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1010 - val_loss: 0.0997
# Epoch 16/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1003 - val_loss: 0.0983
# Epoch 17/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0993 - val_loss: 0.0977
# Epoch 18/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0990 - val_loss: 0.0979
# Epoch 19/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0984 - val_loss: 0.0967
# Epoch 20/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0979 - val_loss: 0.0962
# Epoch 21/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0976 - val_loss: 0.0960
# Epoch 22/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0971 - val_loss: 0.0960
# Epoch 23/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0966 - val_loss: 0.0952
# Epoch 24/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0964 - val_loss: 0.0950
# Epoch 25/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0961 - val_loss: 0.0949
# Epoch 26/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0958 - val_loss: 0.0957
# Epoch 27/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0955 - val_loss: 0.0943
# Epoch 28/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0953 - val_loss: 0.0946
# Epoch 29/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0952 - val_loss: 0.0945
# Epoch 30/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0948 - val_loss: 0.0936
# Epoch 31/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0948 - val_loss: 0.0940
# Epoch 32/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0944 - val_loss: 0.0932
# Epoch 33/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0942 - val_loss: 0.0929
# Epoch 34/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0939 - val_loss: 0.0929
# Epoch 35/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0940 - val_loss: 0.0926
# Epoch 36/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0936 - val_loss: 0.0928
# Epoch 37/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0936 - val_loss: 0.0926
# Epoch 38/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0932 - val_loss: 0.0920
# Epoch 39/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0931 - val_loss: 0.0917
# Epoch 40/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0929 - val_loss: 0.0916
# Epoch 41/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 42/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0926 - val_loss: 0.0913
# Epoch 43/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0923 - val_loss: 0.0915
# Epoch 44/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0921 - val_loss: 0.0915
# Epoch 45/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0922 - val_loss: 0.0908
# Epoch 46/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0920 - val_loss: 0.0907
# Epoch 47/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0918 - val_loss: 0.0908
# Epoch 48/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0918 - val_loss: 0.0907
# Epoch 49/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0916 - val_loss: 0.0912
# Epoch 50/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0915 - val_loss: 0.0905

# %%
decoded_imgs = autoencoder.predict(x_test)

n = 10
plt.figure(figsize=(20, 4))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
encoder = keras.Model(input_img, encoded)
encoded_imgs = encoder.predict(x_test)

n = 10
plt.figure(figsize=(20, 8))
for i in range(1, n + 1):
    ax = plt.subplot(1, n, i)
    plt.imshow(encoded_imgs[i].reshape((4, 4 * 8)).T)
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
# Application to image denoising
from keras.datasets import mnist
import numpy as np

(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape) 
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape) 

x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

# %%
n = 10
plt.figure(figsize=(20, 2))
for i in range(1, n + 1):
    ax = plt.subplot(1, n, i)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
input_img = keras.Input(shape=(28, 28, 1))

x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same')(x)

# At this point the representation is (7, 7, 32)

x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(encoded)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
autoencoder.fit(x_train_noisy, x_train,
                epochs=100,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test_noisy, x_test),
                callbacks=[TensorBoard(log_dir='/tmp/tb', histogram_freq=0, write_graph=False)])
# Out:
# Epoch 1/100
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2767 - val_loss: 0.1150
# Epoch 2/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1140 - val_loss: 0.1078
# Epoch 3/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1081 - val_loss: 0.1046
# Epoch 4/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1053 - val_loss: 0.1028
# Epoch 5/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1035 - val_loss: 0.1014
# Epoch 6/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1021 - val_loss: 0.1002
# Epoch 7/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1010 - val_loss: 0.0994
# Epoch 8/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1000 - val_loss: 0.0984
# Epoch 9/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0991 - val_loss: 0.0979
# Epoch 10/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0987 - val_loss: 0.0974
# Epoch 11/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0982 - val_loss: 0.0971
# Epoch 12/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0978 - val_loss: 0.0968
# Epoch 13/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0974 - val_loss: 0.0963
# Epoch 14/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0969 - val_loss: 0.0961
# Epoch 15/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0966 - val_loss: 0.0958
# Epoch 16/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0964 - val_loss: 0.0957
# Epoch 17/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0965 - val_loss: 0.0955
# Epoch 18/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0961 - val_loss: 0.0965
# Epoch 19/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0960 - val_loss: 0.0953
# Epoch 20/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0957 - val_loss: 0.0952
# Epoch 21/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0956 - val_loss: 0.0953
# Epoch 22/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0956 - val_loss: 0.0954
# Epoch 23/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0954 - val_loss: 0.0948
# Epoch 24/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0954 - val_loss: 0.0949
# Epoch 25/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0952 - val_loss: 0.0947
# Epoch 26/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0952 - val_loss: 0.0948
# Epoch 27/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0951 - val_loss: 0.0948
# Epoch 28/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0950 - val_loss: 0.0945
# Epoch 29/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0950 - val_loss: 0.0945
# Epoch 30/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0949 - val_loss: 0.0944
# Epoch 31/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0949 - val_loss: 0.0943
# Epoch 32/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0947 - val_loss: 0.0943
# Epoch 33/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0948 - val_loss: 0.0945
# Epoch 34/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0947 - val_loss: 0.0942
# Epoch 35/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0946 - val_loss: 0.0943
# Epoch 36/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0946 - val_loss: 0.0942
# Epoch 37/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0946 - val_loss: 0.0942
# Epoch 38/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0947 - val_loss: 0.0943
# Epoch 39/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0942 - val_loss: 0.0942
# Epoch 40/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0943 - val_loss: 0.0941
# Epoch 41/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0943 - val_loss: 0.0942
# Epoch 42/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0942 - val_loss: 0.0943
# Epoch 43/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0943 - val_loss: 0.0944
# Epoch 44/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0942 - val_loss: 0.0939
# Epoch 45/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0941 - val_loss: 0.0938
# Epoch 46/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0941 - val_loss: 0.0938
# Epoch 47/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0942 - val_loss: 0.0940
# Epoch 48/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0942 - val_loss: 0.0938
# Epoch 49/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0943 - val_loss: 0.0944
# Epoch 50/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0940 - val_loss: 0.0938
# Epoch 51/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0942 - val_loss: 0.0939
# Epoch 52/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0941 - val_loss: 0.0938
# Epoch 53/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0940 - val_loss: 0.0938
# Epoch 54/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0939 - val_loss: 0.0938
# Epoch 55/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0941 - val_loss: 0.0937
# Epoch 56/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0939 - val_loss: 0.0937
# Epoch 57/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0938 - val_loss: 0.0936
# Epoch 58/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0939 - val_loss: 0.0936
# Epoch 59/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0938 - val_loss: 0.0937
# Epoch 60/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0938 - val_loss: 0.0937
# Epoch 61/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0939 - val_loss: 0.0936
# Epoch 62/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0938 - val_loss: 0.0936
# Epoch 63/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0938 - val_loss: 0.0937
# Epoch 64/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0939 - val_loss: 0.0936
# Epoch 65/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0938 - val_loss: 0.0938
# Epoch 66/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0938 - val_loss: 0.0936
# Epoch 67/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0938 - val_loss: 0.0936
# Epoch 68/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0936 - val_loss: 0.0940
# Epoch 69/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0937 - val_loss: 0.0935
# Epoch 70/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0935 - val_loss: 0.0935
# Epoch 71/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0934 - val_loss: 0.0936
# Epoch 72/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0936 - val_loss: 0.0934
# Epoch 73/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0936 - val_loss: 0.0936
# Epoch 74/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0936 - val_loss: 0.0935
# Epoch 75/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0935 - val_loss: 0.0935
# Epoch 76/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0935 - val_loss: 0.0934
# Epoch 77/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0937 - val_loss: 0.0934
# Epoch 78/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0935 - val_loss: 0.0936
# Epoch 79/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0935 - val_loss: 0.0934
# Epoch 80/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0934 - val_loss: 0.0936
# Epoch 81/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0936 - val_loss: 0.0935
# Epoch 82/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0933 - val_loss: 0.0935
# Epoch 83/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0935 - val_loss: 0.0932
# Epoch 84/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0933 - val_loss: 0.0933
# Epoch 85/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0934 - val_loss: 0.0935
# Epoch 86/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0935 - val_loss: 0.0933
# Epoch 87/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0933 - val_loss: 0.0935
# Epoch 88/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0935 - val_loss: 0.0935
# Epoch 89/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0936 - val_loss: 0.0933
# Epoch 90/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0934 - val_loss: 0.0934
# Epoch 91/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0933 - val_loss: 0.0933
# Epoch 92/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0933 - val_loss: 0.0933
# Epoch 93/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0934 - val_loss: 0.0932
# Epoch 94/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0933 - val_loss: 0.0932
# Epoch 95/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0933 - val_loss: 0.0932
# Epoch 96/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0934 - val_loss: 0.0934
# Epoch 97/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0933 - val_loss: 0.0937
# Epoch 98/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0933 - val_loss: 0.0932
# Epoch 99/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0934 - val_loss: 0.0933
# Epoch 100/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0934 - val_loss: 0.0932

# %%
# Sequence-to-sequence autoencoder example for future reference
# If your inputs are sequences, rather than vectors or 2D images, then you may want to use as encoder and decoder a type of model that can capture temporal structure, such as a LSTM. To build a LSTM-based autoencoder, first use a LSTM encoder to turn your input sequences into a single vector that contains information about the entire sequence, then repeat this vector n times (where n is the number of timesteps in the output sequence), and run a LSTM decoder to turn this constant sequence into the target sequence.
#timesteps = ...  # Length of your sequences
#input_dim = ... 
#latent_dim = ...

#inputs = keras.Input(shape=(timesteps, input_dim))
#encoded = layers.LSTM(latent_dim)(inputs)

#decoded = layers.RepeatVector(timesteps)(encoded)
#decoded = layers.LSTM(input_dim, return_sequences=True)(decoded)

#sequence_autoencoder = keras.Model(inputs, decoded)
#encoder = keras.Model(inputs, encoded)

# %%
# Variational autoencoder (VAE)
original_dim = 28 * 28
intermediate_dim = 64
latent_dim = 2

inputs = keras.Input(shape=(original_dim,))
h = layers.Dense(intermediate_dim, activation='relu')(inputs)
z_mean = layers.Dense(latent_dim)(h)
z_log_sigma = layers.Dense(latent_dim)(h)

# %%
from keras import backend as K

def sampling(args):
    z_mean, z_log_sigma = args
    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], latent_dim),
                              mean=0., stddev=0.1)
    return z_mean + K.exp(z_log_sigma) * epsilon

z = layers.Lambda(sampling)([z_mean, z_log_sigma])

# %%
# Create encoder
encoder = keras.Model(inputs, [z_mean, z_log_sigma, z], name='encoder')

# Create decoder
latent_inputs = keras.Input(shape=(latent_dim,), name='z_sampling')
x = layers.Dense(intermediate_dim, activation='relu')(latent_inputs)
outputs = layers.Dense(original_dim, activation='sigmoid')(x)
decoder = keras.Model(latent_inputs, outputs, name='decoder')

# instantiate VAE model
outputs = decoder(encoder(inputs)[2])
vae = keras.Model(inputs, outputs, name='vae_mlp')

# %%
reconstruction_loss = keras.losses.binary_crossentropy(inputs, outputs)
reconstruction_loss *= original_dim
kl_loss = 1 + z_log_sigma - K.square(z_mean) - K.exp(z_log_sigma)
kl_loss = K.sum(kl_loss, axis=-1)
kl_loss *= -0.5
vae_loss = K.mean(reconstruction_loss + kl_loss)
vae.add_loss(vae_loss)
vae.compile(optimizer='adam')

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

vae.fit(x_train, x_train,
        epochs=100,
        batch_size=32,
        validation_data=(x_test, x_test))
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 8s 3ms/step - loss: 221.4624 - val_loss: 167.0704
# Epoch 2/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 165.7215 - val_loss: 163.5107
# Epoch 3/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 162.6476 - val_loss: 161.1630
# Epoch 4/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 159.9855 - val_loss: 159.0054
# Epoch 5/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 158.0760 - val_loss: 157.4745
# Epoch 6/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 156.5922 - val_loss: 156.2261
# Epoch 7/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 155.2086 - val_loss: 154.9415
# Epoch 8/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 154.3732 - val_loss: 154.2657
# Epoch 9/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 153.7944 - val_loss: 153.8042
# Epoch 10/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 152.9343 - val_loss: 153.3091
# Epoch 11/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 152.8697 - val_loss: 152.7116
# Epoch 12/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 152.3355 - val_loss: 152.4885
# Epoch 13/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 151.7611 - val_loss: 152.3538
# Epoch 14/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 151.7620 - val_loss: 152.0001
# Epoch 15/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 151.3438 - val_loss: 151.6466
# Epoch 16/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 151.3588 - val_loss: 151.4124
# Epoch 17/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 150.7332 - val_loss: 151.4576
# Epoch 18/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 150.4787 - val_loss: 151.2083
# Epoch 19/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 150.5343 - val_loss: 150.8582
# Epoch 20/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 149.9169 - val_loss: 150.9106
# Epoch 21/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 149.3166 - val_loss: 150.7355
# Epoch 22/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 149.5382 - val_loss: 150.3681
# Epoch 23/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 149.5023 - val_loss: 150.2093
# Epoch 24/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 149.0661 - val_loss: 150.1398
# Epoch 25/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 149.4205 - val_loss: 150.1168
# Epoch 26/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 148.5983 - val_loss: 149.8828
# Epoch 27/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 149.1370 - val_loss: 149.7598
# Epoch 28/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 149.0897 - val_loss: 149.5948
# Epoch 29/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 148.4501 - val_loss: 149.7423
# Epoch 30/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 148.3516 - val_loss: 149.3603
# Epoch 31/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 148.5005 - val_loss: 149.3321
# Epoch 32/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 148.5660 - val_loss: 149.4428
# Epoch 33/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 148.3616 - val_loss: 149.2960
# Epoch 34/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 148.0428 - val_loss: 149.1920
# Epoch 35/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 148.1857 - val_loss: 149.1174
# Epoch 36/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 148.3782 - val_loss: 149.0596
# Epoch 37/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 147.5982 - val_loss: 148.9205
# Epoch 38/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 148.1114 - val_loss: 148.9715
# Epoch 39/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 147.4981 - val_loss: 148.8832
# Epoch 40/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 147.5862 - val_loss: 148.7878
# Epoch 41/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 147.5626 - val_loss: 148.7768
# Epoch 42/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 147.2228 - val_loss: 148.7032
# Epoch 43/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 147.1943 - val_loss: 148.7707
# Epoch 44/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 147.3288 - val_loss: 148.8935
# Epoch 45/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 147.1602 - val_loss: 148.5309
# Epoch 46/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 147.0418 - val_loss: 148.6819
# Epoch 47/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 146.9305 - val_loss: 148.8102
# Epoch 48/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 146.9555 - val_loss: 148.4947
# Epoch 49/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 146.8223 - val_loss: 148.4881
# Epoch 50/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 146.8010 - val_loss: 148.6149
# Epoch 51/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 146.1637 - val_loss: 148.1468
# Epoch 52/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 146.9345 - val_loss: 148.3881
# Epoch 53/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 146.5445 - val_loss: 148.3410
# Epoch 54/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 146.6613 - val_loss: 148.1806
# Epoch 55/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 146.4414 - val_loss: 148.3701
# Epoch 56/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 146.6756 - val_loss: 148.5478
# Epoch 57/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 146.5173 - val_loss: 148.0720
# Epoch 58/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 146.3656 - val_loss: 148.0778
# Epoch 59/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 146.2497 - val_loss: 148.2100
# Epoch 60/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 146.3364 - val_loss: 147.9817
# Epoch 61/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 146.1577 - val_loss: 147.9023
# Epoch 62/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 146.2305 - val_loss: 147.9457
# Epoch 63/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 146.2345 - val_loss: 147.8395
# Epoch 64/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 145.7421 - val_loss: 148.1267
# Epoch 65/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 146.0610 - val_loss: 147.6774
# Epoch 66/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 145.5462 - val_loss: 147.7648
# Epoch 67/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 145.6897 - val_loss: 147.5880
# Epoch 68/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 145.6359 - val_loss: 147.5176
# Epoch 69/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.8927 - val_loss: 147.6100
# Epoch 70/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 145.4844 - val_loss: 147.6126
# Epoch 71/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 145.6536 - val_loss: 147.3990
# Epoch 72/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 145.2041 - val_loss: 147.5589
# Epoch 73/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.2410 - val_loss: 147.6211
# Epoch 74/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 145.3886 - val_loss: 147.1998
# Epoch 75/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 145.7010 - val_loss: 147.6462
# Epoch 76/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.4252 - val_loss: 147.1742
# Epoch 77/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.2779 - val_loss: 147.2720
# Epoch 78/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.2160 - val_loss: 147.0825
# Epoch 79/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.3140 - val_loss: 147.5379
# Epoch 80/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 145.3396 - val_loss: 147.0913
# Epoch 81/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 145.2573 - val_loss: 147.0756
# Epoch 82/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 144.8624 - val_loss: 147.4415
# Epoch 83/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 144.9051 - val_loss: 146.9668
# Epoch 84/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 145.1830 - val_loss: 147.2655
# Epoch 85/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 145.1936 - val_loss: 146.9598
# Epoch 86/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 144.9181 - val_loss: 147.0883
# Epoch 87/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 145.0978 - val_loss: 147.0459
# Epoch 88/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 144.7767 - val_loss: 147.2057
# Epoch 89/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 144.8480 - val_loss: 146.8799
# Epoch 90/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 144.7071 - val_loss: 146.9920
# Epoch 91/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 144.7033 - val_loss: 146.7545
# Epoch 92/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.5496 - val_loss: 147.1051
# Epoch 93/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.6519 - val_loss: 147.0777
# Epoch 94/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.7008 - val_loss: 146.9500
# Epoch 95/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 144.7887 - val_loss: 146.7605
# Epoch 96/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 144.3962 - val_loss: 146.8110
# Epoch 97/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 144.4535 - val_loss: 146.7348
# Epoch 98/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 145.1201 - val_loss: 146.6616
# Epoch 99/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 144.3186 - val_loss: 146.8084
# Epoch 100/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 144.7594 - val_loss: 146.8039

# %%
x_test_encoded = encoder.predict(x_test, batch_size = batch_size)
plt.figure(figsize=(6, 6))
plt.scatter(x_test_encoded[:, 0], x_test_encoded[:, 1], c=y_test)
plt.colorbar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-c426bcf2c5cf> in <module>()
#       2 x_test_encoded = encoder.predict(x_test, batch_size = batch_size)
#       3 plt.figure(figsize=(6, 6))
# ----> 4 plt.scatter(x_test_encoded[:, 0], x_test_encoded[:, 1], c=y_test)
#       5 plt.colorbar()
#       6 plt.show()
#
# TypeError: list indices must be integers or slices, not tuple

# %%
# Display a 2D manifold of the digits
n = 15  # figure with 15x15 digits
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))
# We will sample n points within [-15, 15] standard deviations
grid_x = np.linspace(-15, 15, n)
grid_y = np.linspace(-15, 15, n)

for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        x_decoded = decoder.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit

plt.figure(figsize=(10, 10))
plt.imshow(figure)
plt.show()
